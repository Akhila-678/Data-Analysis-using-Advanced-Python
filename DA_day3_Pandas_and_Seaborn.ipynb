# %% [markdown]
# Pandas:
#
#
# *   Used for data manipulation  (Data cleaning, Organizing data)
# *   Creates dataframes from excel, csv , text , DBs
# *   Dataframe (rows and columns readable by python)
# *   Data cleaning by dropping or replacing with mean
# *   Visualize the data

# %%
#importing
import pandas as pd

# %% [markdown]
# Series

# %%
names = ["Akhila","Sasi","Prasanna","Lavanya"]
index = [67,89,85,65]
ser1 = pd.Series(names,index)

# %%
print(ser1)
# Out:
# 67      Akhila
# 89        Sasi
# 85    Prasanna
# 65     Lavanya
# dtype: object

# %% [markdown]
# Importing files
#
# *   for csv and txt : read_csv("file path")
# *   for excel : read_excel("file path")

# %%
df = pd.read_csv("/content/diabetcsv.csv")

# %%
df.head(10)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive
# 7    10   115     0     0     0  35.3  0.134   29  tested_negative
# 8     2   197    70    45   543  30.5  0.158   53  tested_positive
# 9     8   125    96     0     0   0.0  0.232   54  tested_positive

# %%
df.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
dft1=pd.read_csv("/content/archive (4).zip")

# %%
dft1.tail()
# Out:
#        label                                               text
# 83443      0  hi given a date how do i get the last date of ...
# 83444      1  now you can order software on cd or download i...
# 83445      1  dear valued member canadianpharmacy provides a...
# 83446      0  subscribe change profile contact us long term ...
# 83447      1  get the most out of life ! viagra has helped m...

# %%
dft2=pd.read_csv("/content/grades_withnulls.txt")

# %%
dft2.tail()
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
dfe = pd.read_excel("/content/diabetes.xlsx")

# %%
dfe.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
dft1=pd.read_csv("/content/archive (4).zip")
print(dft1.describe)
# Out:
# <bound method NDFrame.describe of        label                                               text
# 0          1  ounce feather bowl hummingbird opec moment ala...
# 1          1  wulvob get your medircations online qnb ikud v...
# 2          0   computer connection from cnn com wednesday es...
# 3          1  university degree obtain a prosperous future m...
# 4          0  thanks for all your answers guys i know i shou...
# ...      ...                                                ...
# 83443      0  hi given a date how do i get the last date of ...
# 83444      1  now you can order software on cd or download i...
# 83445      1  dear valued member canadianpharmacy provides a...
# 83446      0  subscribe change profile contact us long term ...
# 83447      1  get the most out of life ! viagra has helped m...
#
# [83448 rows x 2 columns]>

# %%
dft2=pd.read_csv("/content/grades_withnulls.txt")
print(dft2.shape)      #Get the number of rows and columns
print(dft2.shape[0])   #Get the number of rows only
print(dft2.shape[1])   #Get the number of columns only
# Out:
# (17, 1)
# 17
# 1

# %%
#creating a list with all column names
print(dft2.columns)
# Out:
# Index(['Names Initials SEM1 SEM2 SEM3 Grade Placed'], dtype='object')

# %% [markdown]
# Accessing Data
#
# *   loc - accepts column names and index
# *   iloc - accepts only index

# %%
print(dft1[2:5])     #to access rows
# Out:
#    label                                               text
# 2      0   computer connection from cnn com wednesday es...
# 3      1  university degree obtain a prosperous future m...
# 4      0  thanks for all your answers guys i know i shou...

# %%
print(dft1.loc[2:5,["label"]])    #rows of specified columns
# Out:
#    label
# 2      0
# 3      1
# 4      0
# 5      0

# %%
print(dft1.iloc[2:5, :2])    #iloc[row range , column range] =>index
# Out:
#    label                                               text
# 2      0   computer connection from cnn com wednesday es...
# 3      1  university degree obtain a prosperous future m...
# 4      0  thanks for all your answers guys i know i shou...

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")

# %%
dfn.head(10)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1
# 8    Jess        K   NaN   9.1   9.9    A+       1
# 9  Rajini        M   NaN   9.1   9.3     A       0

# %%
dfn.isnull().head(10)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False
# 7  False     False  False  False  False  False   False
# 8  False     False   True  False  False  False   False
# 9  False     False   True  False  False  False   False

# %%
#to view how many nulls we have per column
dfn.isnull().sum()
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
#to view total nulls
dfn.isnull().sum().sum()
# Out:
# 4

# %% [markdown]
# Dropping Nulls

# %%
dfc = dfn.dropna()

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#replace null with specifies value
dfc1 = dfn.fillna(5)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Cleaning with mean

# %%
m = dfn["SEM3"].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dfc2 = dfn.fillna(m)
dfc2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Drop duplicate rows

# %%
dropped = dfc2.drop_duplicates()
dropped
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Columns

# %%
#df.rename(columns = {old:new})
dfc2.rename(columns = {"Grade":"GPA"} , inplace= True)

# %%
dfc2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0      Joe        K   9.8  10.0   9.9  A+       1
# 1   Rajesh        M   8.9   9.1   9.3   A       1
# 2   Kissan        V   9.9   9.8  10.0   A       0
# 3     Mary        N   7.7   8.0   9.1   B       0
# 4     Jeen        K   9.8   9.1   9.9  A+       1
# 5      Raj        M   8.9   9.1   9.3   A       1
# 6   Hassan        V   9.9   9.0   9.2   A       1
# 7     Mari        N   7.7   8.0   7.1   B       1
# 8     Jess        K   9.1   9.1   9.9  A+       1
# 9   Rajini        M   9.1   9.1   9.3   A       0
# 10   Kiran        V   9.1   9.3   9.2   A       0
# 11    Maya        N   7.7   8.0   7.1   B       0
# 12   Jolin        K   9.8   9.1   9.9  A+       1
# 13  Rajesh        M   8.9   9.1   9.3   A       1
# 14    Riya        M   9.3   9.9  10.0   A       1
# 15    Sana        V   9.9   9.3   9.2   A       0
# 16    Mark        N   7.7   8.0   7.0   B       0

# %%
#dataframe_name["new_column"] = values
dfc2["Avg_score"] = (dfc2["SEM1"] + dfc2["SEM2"] + dfc2["SEM3"])/3

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9  A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.3   A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.0   A       0   9.900000
# 3    Mary        N   7.7   8.0   9.1   B       0   8.266667
# 4    Jeen        K   9.8   9.1   9.9  A+       1   9.600000

# %%
dfc2[["SEM1","SEM2"]].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# Seaborn

# %%
import seaborn as sns

# %%
pl = sns.lineplot(x="Names", y="SEM1", data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x = "SEM2" , y="SEM1" , col="Placed"
)

# %% [markdown]
# Load Diabeties.csv
#
#
# *   Create relplot with age in the x-axis and class as columns

# %%
import pandas as pd

# %%
dfd = pd.read_csv("/content/diabetcsv.csv")
dfd
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dfd["Index"]=range(1,769)
print(dfd)
sns.relplot(
    data=dfd,
    x="Index" , y="age" , col="class"
)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %% [markdown]
# Inbulit Datasets in Seaborn
#
# *   tips
# *   dowjones
# *   fmri
# *   dots
# *   healthexp
# *   To load dataset : load_dataset("ds name")
#
# *   hue - creating difference based on a column via colors
# *   style - different marker for different category
# *   Color Palette - pastel , bright , dark , muted , deep , colorblind

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dowjones = sns.load_dataset("dowjones")

# %%
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
fmri = sns.load_dataset("fmri")

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dots = sns.load_dataset("dots")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
healthexp = sns.load_dataset("healthexp")

# %%
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.relplot(
    data=tips , x="total_bill" , y="tip" , col="time"
)

# %%
#hue - creating difference based on a column via colors
sns.relplot(
    data=tips , x="total_bill" , y="tip" , hue="time"
)

# %%
sns.relplot(
    data=tips , x="total_bill" , y="tip" , col="day"
)

# %%
sns.relplot(
    data=tips , x="total_bill" , y="tip" , hue="day"
)

# %%
sns.relplot(
    data=tips , x="total_bill" , y="tip" , col="size"
)

# %%
sns.relplot(
    data=tips , x="total_bill" , y="tip" , hue="size"
)

# %%
#marker
sns.relplot(
    data=tips,
    x="total_bill" , y="tip" , hue="smoker" , style="time"
)

# %%
sns.relplot(
    data=tips,
    x="total_bill" , y="tip" , hue="time" , style="day"
)

# %%
c

# %%
sns.relplot(
    data=tips,
    x="total_bill" , y="tip" , hue="day" , style="size" , palette = "pastel"
)

# %%
sns.relplot(
    data=dowjones,
    x="Date" , y="Price" , kind="line"
)

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(
    data=fmri,
    x="timepoint" , y="signal" , col ="region"
)

# %%
sns.catplot(
    data=tips,
    x="total_bill" , y="day"
)

# %%
sns.catplot(
    data=tips,
    x="total_bill" , y="size"
)

# %%
sns.relplot(
    data=fmri,
    x="region" , y="signal"
)

# %%
sns.catplot(
    data=fmri,
    x="region" , y="signal"
)

# %%
sns.catplot(
    data=tips,
    x="time" , y="total_bill" , hue="smoker", kind="violin"
)

# %% [markdown]
# Linear Fit
#
# *   Plotting the dataset
# *   Fitting the line
# *   Determining

# %%
sns.lmplot(x="size" , y="tip" , data=tips)

# %% [markdown]
# 1.   Web Scrapping -
#
# *   Loading the data from the websites
# *   Unstructured in HTML
# *   Covertible into spreadsheets/DB
# *   Major websites have their APIs from web scrapping
#
#
#
# 2.   Scrapper -
#
# *   Extract all the data on particular sites
# *   Specific data that a user wants
#
# *   Process:
#
#     *   URL ->
#     *   HTML code ->
#     *   Elemnts(CSS/JS)
#     *   Scrapes the required format(csv,xlsv,json)
#
# 3.   Applications -
#
# *   Email Marketing
# *   Sentiment Analysis
# *   News Monitoring
# *   Market Research
# *   Price Monitoring

# %% [markdown]
# Libraries
#
#
# *   BeautifulSoup - it scoops out the HTML code
# *   Requests - used to send request to a webpage
# *   Pandas -
# *   Selenium
# *   webdriver
# *   webdriver_manager
#
# *   To install any library
#         *   !pip install library
#         *   !pip install --upgrade library - to upgrade to recent version
#
# *   Importing Subpackage
#         *   from parent import child

# %% [markdown]
# BeautifulSoup
#
#
# *   Used to scrape data from Static Website
# *   Package bs4 : Subpackage BeautifulSoup
#
#
# *   BeautifulSoup() - to extract html code from a webpage
#                                                         *   .text
#                                                         *   .html
#
# *   find() - to find first element of a kind
#                                                         *   (element_name)
#
# *   find_all() - to find all elements of a kind
#                                                         *   (element_name)

# %% [markdown]
# Requests
#
#
# *   Used to send request to a web page
# *   get('url')
